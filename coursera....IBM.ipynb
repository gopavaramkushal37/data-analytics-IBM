# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d=pd.read_csv("kc_house_data_NaN.csv")

# %%
d
# Out:
#        Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0               0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1               1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2               2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3               3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4               4  1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...         ...              ...       ...       ...        ...
# 21608       21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609       21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610       21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611       21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612       21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
# ...

# %%
d.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#Question 1

# %%
d.dtypes
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
#Question 2

# %%
d.drop(['id', 'Unnamed: 0'], axis=1, inplace=True)
d.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21600.000000  21603.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.372870      2.115736   2079.899736  1.510697e+04
# std    3.671272e+05      0.926657      0.768996    918.440897  4.142051e+04
# min    7.500000e+04      1.000000      0.500000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
print("number of NaN values for the column bedrooms :", d['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", d['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 13
# number of NaN values for the column bathrooms : 10

# %%
mean=d['bathrooms'].mean()
d['bathrooms'].replace(np.nan,mean, inplace=True)

# %%
mean
# Out:
# 2.1157362403369904

# %%
print("number of NaN values for the column bedrooms :", d['bedrooms'].isnull().sum())
print("number of NaN values for the column bathrooms :", d['bathrooms'].isnull().sum())
# Out:
# number of NaN values for the column bedrooms : 0
# number of NaN values for the column bathrooms : 0

# %%
#Question 3

# %%
d['floors'].value_counts().to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
#Question 4

# %%
sns.boxplot(x='waterfront', y='price', data=d)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
#Question 5

# %%
sns.regplot(x='sqft_above', y='price', data=d)
# Out:
# <AxesSubplot:xlabel='sqft_above', ylabel='price'>

# %%
#Question 6

# %%
from sklearn.linear_model import LinearRegression

# %%
X = d[['long']]
Y = d['price']
lm = LinearRegression()
lm
lm.fit(X,Y)
lm.score(X, Y)
# Out:
# 0.00046769430149029567

# %%
X = d[['sqft_living']]
Y = d['price']
lm = LinearRegression()
lm.fit(X, Y)
lm.score(X, Y)
# Out:
# 0.4928532179037931

# %%
#Question 7

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]

# %%
X = d[features]
Y= d['price']
lm = LinearRegression()
lm.fit(X, Y)
lm.score(X, Y)
# Out:
# 0.6576951666037498

# %%
#Question 9

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
print("done")
# Out:
# done

# %%
features =["floors", "waterfront","lat" ,"bedrooms" ,"sqft_basement" ,"view" ,"bathrooms","sqft_living15","sqft_above","grade","sqft_living"]    
X = d[features ]
Y = d['price']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=1)


print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 3242
# number of training samples: 18371

# %%
from sklearn.linear_model import Ridge

# %%
RidgeModel = Ridge(alpha = 0.1)
RidgeModel.fit(x_train, y_train)
RidgeModel.score(x_test, y_test)
# Out:
# 0.647875916393911

# %%
#Question 10

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
pr = PolynomialFeatures(degree=2)
x_train_pr = pr.fit_transform(x_train)
x_test_pr = pr.fit_transform(x_test)
poly = Ridge(alpha=0.1)
poly.fit(x_train_pr, y_train)
poly.score(x_test_pr, y_test)
# Out:
# 0.7002744261580325
